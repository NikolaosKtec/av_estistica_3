# %% [markdown]
# <p>Aplique os dois tipos de estatística de teste para realizar um teste de comparação de médias. Você pode utilizar diferentes métodos estatísticos, dependendo das características dos seus
# dados e do objetivo da comparação. Os dois métodos comuns: o teste t de Student (2 var
# independentes) e a análise de variância- ANOVA (mais de um var independentes). Escolha umadas variáveis independentes e aplique o teste. INTERPRETE OS RESULTADOS (2 PONTOS)
# Teste t-Student
# H0: Não existe diferenca das produções agrícolas diante das duas metodologias de cultivo H1: Existe diferenca entre as produções agricolas da batata doce e batata inglesa quando se observa a questao do tipo de metodologia de cultivo (2 tratamento)
# Teste ANOVA
# H0: Não existe diferenca das produções agrícolas diante das três tratamentos do espaçamento de cultivo H1: Existe diferenca entre as produções agricolas da batata doce e batata inglesa quando se observa as questoes dos tipos de espacamento entre uma muda e outra (3 tratamento)</p>

# %%
# import sys
# sys.path.append('./quests')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
from sklearn.linear_model import LinearRegression
from functions import prodT_por_palhaEdireto,prod_por_palhaEdireto,get_median_quartil_q7,get_median_quartil_q7_prd,prodT_por_espacamen,get_quartil_espacamen,prod_por_espacamen

# Criação do modelo de regressão linear
regressor = LinearRegression()

data = pd.read_excel('BDAgro.xlsx')
# print(data)
pd.__version__
# %matplotlib inline

# %% [markdown]
# <p>Teste t-Student
# H0: Não existe diferenca das produções agrícolas diante das duas metodologias de cultivo </p>

# %%
prodT_metd_direto, prodT_metd_palha = prodT_por_palhaEdireto(data)

# %%
#obtem medias e quartis
media_prod_metd_Di, media_prod_metd_Pa, quartil_direto, quartil_palha = get_median_quartil_q7(prodT_metd_direto,prodT_metd_palha)

# %%
# plotagem
fig, ax = plt.subplots(1,2,figsize=(11,4))

quartil = ['Q1', 'Q2', 'Q3']
bar_labels = ['quartil_1','quartil_2','quartil_3']
bar_colors = ['tab:purple', 'tab:blue', 'tab:pink',]

ax[0].bar(quartil,  quartil_direto, label=bar_labels, color=bar_colors,width=[0.5])

ax[0].set_ylabel('produção total:')
ax[0].set_title('plantio direto')
ax[0].legend(title='Estados')


ax[1].bar(quartil, quartil_palha, label=bar_labels, color=bar_colors,width=[0.5])

ax[1].set_ylabel('produção total:')
ax[1].set_title('plantio com palha')
ax[1].legend(title='tips')

print(f'media e desvio padrão:')

print(f'media cultivo direto: { np.floor(media_prod_metd_Di) }')
print(f'desvio padrao Cdireto>>> {np.std(prodT_metd_direto["prod_total"])}')

print(f'media cultivo com palha: { np.floor(media_prod_metd_Pa) }')
print(f'desvio padrao Cpalha>>> {np.std(prodT_metd_palha["prod_total"])}')
plt.show()
# Out:
# media e desvio padrão:
# media cultivo direto: 55508.0
# desvio padrao Cdireto>>> 31547.334317465804
# media cultivo com palha: 55865.0
# desvio padrao Cpalha>>> 31999.41211657836

# %% [markdown]
# <p>H1: Existe diferenca entre as produções agricolas da batata doce e batata inglesa quando se observa a questao do tipo de metodologia de cultivo</p>

# %%
metd_direto, metd_palha = prod_por_palhaEdireto( data['ProdBd'], data)
media_prod_metd_Di, media_prod_metd_Pa, quartil_direto, quartil_palha = get_median_quartil_q7_prd(metd_direto,metd_palha)

# %%
# plotagem
fig, ax = plt.subplots(1,2,figsize=(11,4))

quartil = ['Q1', 'Q2', 'Q3']
bar_labels = ['quartil_1','quartil_2','quartil_3']
bar_colors = ['tab:purple', 'tab:blue', 'tab:pink',]

ax[0].bar(quartil,  quartil_direto, label=bar_labels, color=bar_colors,width=[0.5])

ax[0].set_ylabel('produção de batata doce:')
ax[0].set_title('plantio direto')
ax[0].legend(title='tips')


ax[1].bar(quartil, quartil_palha, label=bar_labels, color=bar_colors,width=[0.5])

ax[1].set_ylabel('produção de batata doce:')
ax[1].set_title('plantio com palha')
ax[1].legend(title='tips')

print(f'media e desvio padrão:')

print(f'media cultivo direto: { np.floor(media_prod_metd_Di) }')
print(f'desvio padrao Cdireto>>> {np.std(metd_direto["prod"])}')

print(f'media cultivo com palha: { np.floor(media_prod_metd_Pa) }')
print(f'desvio padrao Cpalha>>> {np.std(metd_palha["prod"])}')
plt.show()
# Out:
# media e desvio padrão:
# media cultivo direto: 49990.0
# desvio padrao Cdireto>>> 28915.5843222524
# media cultivo com palha: 50346.0
# desvio padrao Cpalha>>> 29396.02290966964

# %% [markdown]
# <p>Não existe diferenca das produções agrícolas diante das três tratamentos do espaçamento de cultivo H1: Existe diferenca entre as produções agricolas da batata doce e batata inglesa quando se observa as questoes dos tipos de espacamento entre uma muda e outra (3 tratamento)</p>

# %%
prodT_esp05, prodT_esp10, prodT_esp15 = prodT_por_espacamen(data)
esp05, esp10, esp15 = get_quartil_espacamen(prodT_esp05, prodT_esp10, prodT_esp15)

# %%
# plotagem
fig, ax = plt.subplots(2,2,figsize=(8,12))

quartil = ['Q1', 'Q2', 'Q3']
bar_labels = ['quartil_1','quartil_2','quartil_3']
bar_colors = ['tab:purple', 'tab:blue', 'tab:pink',]

ax[0][0].bar(quartil,  esp05, label=bar_labels, color=bar_colors,width=[0.5])

ax[0][0].set_ylabel('produção de batata doce:')
ax[0][0].set_title('distancia de plantio 0.5')
ax[0][0].legend(title='tips')


ax[0][1].bar(quartil, esp10, label=bar_labels, color=bar_colors,width=[0.5])

ax[0][1].set_ylabel('produção de batata doce:')
ax[0][1].set_title('distancia de plantio 1.0')
ax[0][1].legend(title='tips')

ax[1][0].bar(quartil, esp15, label=bar_labels, color=bar_colors,width=[0.5])

ax[1][0].set_ylabel('produção de batata doce:')
ax[1][0].set_title('distancia de plantio 1.5')
ax[1][0].legend(title='tips')
print (f'media do espaçamento 0.5: { np.mean(prodT_esp05["prod"])}' )
print (f'media do espaçamento 1.0: { np.mean(prodT_esp10["prod"])}' )
print (f'media do espaçamento 1.5: { np.mean(prodT_esp15["prod"])}' )

plt.show()
# Out:
# media do espaçamento 0.5: 54893.03
# media do espaçamento 1.0: 55474.35
# media do espaçamento 1.5: 56693.99

# %% [markdown]
# <p>Existe diferenca entre as produções agricolas da batata doce e batata inglesa quando se observa as questoes dos tipos de espacamento entre uma muda e outra </p>

# %%
prodT_esp05, prodT_esp10, prodT_esp15 = prod_por_espacamen(data)

# %%
print (f'media do espaçamento 0.5 batata doce: { np.mean(prodT_esp05["prodBd"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp05["prodBd"])}')

print (f'media do espaçamento 1.0 batata doce: { np.mean(prodT_esp10["prodBd"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp10["prodBd"])}')

print (f'media do espaçamento 1.5 batata doce: { np.mean(prodT_esp15["prodBd"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp15["prodBd"])}')
# Out:
# media do espaçamento 0.5 batata doce: 49428.03
# desvio padrao >>> 28975.929122447484
# media do espaçamento 1.0 batata doce: 49959.55
# desvio padrao >>> 28752.685647213897
# media do espaçamento 1.5 batata doce: 51118.86
# desvio padrao >>> 29709.1604920166
# desvio padrao >>> 882634217.1404

# %%
print (f'media do espaçamento 0.5 batata doce: { np.mean(prodT_esp05["prodBi"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp05["prodBi"])}')

print (f'media do espaçamento 1.0 batata doce: { np.mean(prodT_esp10["prodBi"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp10["prodBi"])}')

print (f'media do espaçamento 1.5 batata doce: { np.mean(prodT_esp15["prodBi"])}' )
print(f'desvio padrao >>> {np.std(prodT_esp15["prodBi"])}')
# Out:
# media do espaçamento 0.5 batata doce: 5465.0
# desvio padrao >>> 2638.6368033513063
# media do espaçamento 1.0 batata doce: 5514.8
# desvio padrao >>> 2619.4291133756606
# media do espaçamento 1.5 batata doce: 5575.13
# desvio padrao >>> 2628.9961036677096
# desvio padrao >>> 6911620.513099999
